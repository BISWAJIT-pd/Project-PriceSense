# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df=pd.read_csv('/content/geography_occasion (1).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47581 entries, 0 to 47580
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   order_id   47581 non-null  object
#  1   state      47581 non-null  object
#  2   city_tier  47581 non-null  object
#  3   occasion   47581 non-null  object
# dtypes: object(4)
# memory usage: 1.5+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sample(10)
# Out:
#         order_id       state city_tier           occasion
# 21935  ORD023011     Florida    Tier 1  religious-fasting
# 6871   ORD007226     Florida    Tier 3      marathon-prep
# 21565  ORD022631    Illinois    Tier 3        daily snack
# 15540  ORD016290  Washington    Tier 1      marathon-prep
# 32101  ORD033680    New York    Tier 1         late-night
# 37782  ORD039642    Colorado    Tier 3            festive
# 28821  ORD030231     Georgia    Tier 2         late-night
# 21521  ORD022584    Illinois    Tier 1  religious-fasting
# 18102  ORD018977  Washington    Tier 1          on-the-go
# 40330  ORD042337    Colorado   Unknown  religious-fasting

# %%
df['order_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['state'].value_counts()
# Out:
# state
# NY            4898
# Illinois      4809
# Calfornia     4771
# New York      4758
# California    4755
# Colorado      4748
# Washington    4743
# Texas         4734
# Florida       4688
# Georgia       4677
# Name: count, dtype: int64

# %%
#As we see in state column many names are same
state_mapping = {
    'NY': 'New York',
    'Illinois': 'Illinois',
    'Calfornia': 'California',
    'New York': 'New York',
    'California': 'California',
    'Colorado': 'Colorado',
    'Washington': 'Washington',
    'Texas': 'Texas',
    'Florida': 'Florida'
}

df['state'] = df['state'].replace(state_mapping)

# %%
df['state'].value_counts()
# Out:
# state
# New York      9656
# California    9526
# Illinois      4809
# Colorado      4748
# Washington    4743
# Texas         4734
# Florida       4688
# Georgia       4677
# Name: count, dtype: int64

# %%
plt.pie(df['state'].value_counts(),labels=df['state'].value_counts().index,autopct='%1.1f%%')
plt.show()

# %%
df['city_tier'].value_counts()
# Out:
# city_tier
# Tier 1     18960
# Tier 2     14345
# Tier 3      9585
# Unknown     4691
# Name: count, dtype: int64

# %%
df[['city_tier', 'state']].value_counts().reset_index(name='count')
# Out:
#    city_tier       state  count
# 0     Tier 1  California   3857
# 1     Tier 1    New York   3819
# 2     Tier 2    New York   2985
# 3     Tier 2  California   2812
# 4     Tier 1    Colorado   1924
# 5     Tier 3  California   1908
# 6     Tier 1  Washington   1905
# 7     Tier 1    Illinois   1901
# 8     Tier 3    New York   1898
# 9     Tier 1     Florida   1897
# 10    Tier 1     Georgia   1851
# 11    Tier 1       Texas   1806
# 12    Tier 2       Texas   1517
# 13    Tier 2    Illinois   1441
# 14    Tier 2  Washington   1421
# 15    Tier 2     Florida   1405
# 16    Tier 2     Georgia   1396
# 17    Tier 2    Colorado   1368
# 18    Tier 3    Colorado    985
# 19    Tier 3    Illinois    976
# 20    Tier 3       Texas    973
# 21    Tier 3     Georgia    962
# 22    Tier 3  Washington    956
# 23   Unknown    New York    954
# 24   Unknown  California    949
# 25    Tier 3     Florida    927
# 26   Unknown    Illinois    491
# 27   Unknown    Colorado    471
# ...

# %%
df['occasion'].value_counts()
# Out:
# occasion
# late-night           12323
# religious-fasting     6533
# on-the-go             4913
# festive               4901
# daily snack           4831
# gym                   4764
# road-trip             4721
# marathon-prep         4595
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47581 entries, 0 to 47580
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   order_id   47581 non-null  object
#  1   state      47581 non-null  object
#  2   city_tier  47581 non-null  object
#  3   occasion   47581 non-null  object
# dtypes: object(4)
# memory usage: 1.5+ MB

# %%
from google.colab import files
df.to_csv('cleaned_dgeographic_occasion1.csv', index=False)
files.download('cleaned_geographic_occasion1.csv')
